# %%
pip install pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.6/12.6 MB 3.8 MB/s eta 0:00:0000:0100:01m
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 505.5/505.5 kB 496.9 kB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 814.3 kB/s eta 0:00:0000:0100:01
# ...
#
# [notice] A new release of pip is available: 23.1.2 -> 24.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas

# %%
data = pandas.read_csv('tips.csv')

data
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
tot_bil = data['total_bill']
tip = data['tip']

# %%
import matplotlib.pyplot as plt 
plt.plot(tot_bil,tip,'x')
plt.xlabel('total bill')
plt.ylabel('tip')
# Out:
# Text(0, 0.5, 'tip')

# %%
import pandas

# %%
addata = pandas.read_csv('advertising.csv')

addata
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
tvprice = addata['TV']

# %%
total = addata['TV'] + addata['radio'] + addata['newspaper']

# %%
import matplotlib.pyplot as plt 
plt.plot(tvprice)

# %%
sales = addata['sales']

# %%
plt.plot(sales,total,'o')

# %%
addata['total'] = total

# %%
pip install seaborn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 328.8 kB/s eta 0:00:00a 0:00:01
# ...
#
# [notice] A new release of pip is available: 23.1.2 -> 24.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
sns.regplot(x = 'sales',y = 'total',data = addata)
# Out:
# <Axes: xlabel='sales', ylabel='total'>

# %%
sns.scatterplot(x='total_bill',y = 'tip',data = data,hue='time')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
import pandas as pd

# %%
tips = pd.read_csv('tips.csv')

# %%
#Violin Plot
sns.violinplot(data=tips, x='day', y='tip')
plt.show()
