# %%
import pandas

# %%
Data = pandas.read_csv('house_size_price_data.csv')

# %%
Data
# Out:
#      House_Size_Sqft   House_Price
# 0        1810.890416  3.212921e+05
# 1        3827.500072  1.221056e+06
# 2        3061.978796  1.414051e+06
# 3        2595.304695  1.088037e+06
# 4        1046.065242  5.377720e+05
# ..               ...           ...
# 995       820.537257  3.194375e+05
# 996      3710.597514  1.891974e+06
# 997       978.865208  2.793089e+05
# 998      3825.830738  4.405966e+05
# 999      2061.020205  3.947431e+05
#
# [1000 rows x 2 columns]

# %%
X = Data[['House_Size_Sqft']]
Y = Data['House_Price']

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(X,Y,'x')
plt.xlabel('Size')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
from sklearn.linear_model import LinearRegression

# %%
asad = LinearRegression()

# %%
asad.fit(X,Y)
# Out:
# LinearRegression()

# %%
asad.predict([[100]])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([66963.12215768])

# %%
import numpy as np

# %%
x = np.linspace(0,5000,50000)

# %%
y = asad.predict(x.reshape(len(x),1))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
plt.plot(X,Y,'x')
plt.plot(x,y)
plt.title('Asad prediction model for house')
plt.xlabel('Size')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')
